# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Generate synthetic data
"""np.random.seed(42)
num_samples = 100
house_size = np.random.randint(800, 4000, num_samples)
bedrooms = np.random.randint(1, 6, num_samples)
price = 200000 + 150 * house_size + 50000 * bedrooms + np.random.normal(0, 100000, num_samples)

data = pd.DataFrame({'HouseSizeSqft': house_size, 'Bedrooms': bedrooms, 'Price': price})
data.to_csv('E:\Work\Data analysis\Data analysis projects\Linear regression\housing_data.csv', index = False)"""

# %%
# Read data
data = pd.read_csv('housing_data.csv')
# Check the first few rows of data
print(data.head())

# Plot the data
plt.scatter(data['HouseSizeSqft'], data['Price'])
plt.xlabel('House Size (sqft)')
plt.ylabel('Price')
plt.title('House Prices vs. Size')
plt.show()
# Out:
#    HouseSizeSqft  Bedrooms         Price
# 0           3974         4  1.002123e+06
# 1           1660         5  9.453242e+05
# 2           2094         1  5.448639e+05
# 3           1930         5  7.696547e+05
# 4           1895         5  7.307788e+05

# %%
# Prepare the data
X = data[['HouseSizeSqft', 'Bedrooms']]
#X = data[['HouseSizeSqft']]
Y = data['Price']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state= 42)

# %%
# Create a linear regression object
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
Y_pred = model.predict(X_test)

# Calculate mean squared error and R-squared
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test,Y_pred)

print('mse = ', mse)
print('r2 = ', r2)
# Out:
# mse =  9297252012.034367
# r2 =  0.6714723529456343

# %%
#Plot the regression model line
plt.scatter(Y_test, Y_pred, color='grey') 
plt.plot(Y_test, Y_test, color='red', linewidth=2)
plt.xlabel('True Prices')
plt.ylabel('Predicted Prices')
plt.title('True Prices vs. Predicted Prices')
plt.show()
